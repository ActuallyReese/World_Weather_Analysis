# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the API key.
from config import g_key
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | mutsamudu
# City not found. Skipping...
# Processing Record 2 of Set 1 | indian head
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | saint-philippe
# Processing Record 6 of Set 1 | cidreira
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | nizhniy tsasuchey
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | vila
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | lebu
# Processing Record 14 of Set 1 | cayenne
# Processing Record 15 of Set 1 | kodiak
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | roald
# Processing Record 18 of Set 1 | azul
# Processing Record 19 of Set 1 | limoges
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | esperance
# Processing Record 23 of Set 1 | marzuq
# Processing Record 24 of Set 1 | cap malheureux
# Processing Record 25 of Set 1 | pakokku
# Processing Record 26 of Set 1 | khatanga
# Processing Record 27 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 1 | sokoto
# Processing Record 29 of Set 1 | bababe
# City not found. Skipping...
# Processing Record 30 of Set 1 | sibolga
# Processing Record 31 of Set 1 | leh
# Processing Record 32 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 1 | ancud
# Processing Record 34 of Set 1 | atuona
# Processing Record 35 of Set 1 | port blair
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | acari
# Processing Record 38 of Set 1 | touros
# Processing Record 39 of Set 1 | vestmannaeyjar
# Processing Record 40 of Set 1 | chokurdakh
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | semporna
# Processing Record 43 of Set 1 | trinidad
# Processing Record 44 of Set 1 | gold coast
# Processing Record 45 of Set 1 | mangit
# Processing Record 46 of Set 1 | thompson
# Processing Record 47 of Set 1 | nouadhibou
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | tucuman
# Processing Record 50 of Set 1 | katsuura
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | hithadhoo
# Processing Record 4 of Set 2 | ponta do sol
# Processing Record 5 of Set 2 | lasa
# Processing Record 6 of Set 2 | hobart
# Processing Record 7 of Set 2 | ambodifototra
# City not found. Skipping...
# Processing Record 8 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 2 | carnarvon
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | chifeng
# Processing Record 12 of Set 2 | kruisfontein
# Processing Record 13 of Set 2 | lodja
# Processing Record 14 of Set 2 | longyearbyen
# Processing Record 15 of Set 2 | khorixas
# Processing Record 16 of Set 2 | kirkuk
# Processing Record 17 of Set 2 | boysun
# Processing Record 18 of Set 2 | na wa
# Processing Record 19 of Set 2 | bathsheba
# Processing Record 20 of Set 2 | natal
# Processing Record 21 of Set 2 | gat
# Processing Record 22 of Set 2 | bambous virieux
# Processing Record 23 of Set 2 | solnechnyy
# Processing Record 24 of Set 2 | itoman
# Processing Record 25 of Set 2 | wawa
# Processing Record 26 of Set 2 | saint george
# Processing Record 27 of Set 2 | nikolskoye
# Processing Record 28 of Set 2 | kavieng
# Processing Record 29 of Set 2 | barrow
# Processing Record 30 of Set 2 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 31 of Set 2 | margate
# Processing Record 32 of Set 2 | hobyo
# Processing Record 33 of Set 2 | saskylakh
# Processing Record 34 of Set 2 | kilifi
# Processing Record 35 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 2 | georgetown
# Processing Record 37 of Set 2 | villa bruzual
# Processing Record 38 of Set 2 | tuktoyaktuk
# Processing Record 39 of Set 2 | ribeira grande
# Processing Record 40 of Set 2 | tiksi
# Processing Record 41 of Set 2 | pandharpur
# Processing Record 42 of Set 2 | pingliang
# Processing Record 43 of Set 2 | provideniya
# Processing Record 44 of Set 2 | aragarcas
# Processing Record 45 of Set 2 | kununurra
# Processing Record 46 of Set 2 | arraial do cabo
# Processing Record 47 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 2 | egvekinot
# Processing Record 49 of Set 2 | vao
# Processing Record 50 of Set 2 | coquimbo
# Processing Record 1 of Set 3 | nanortalik
# Processing Record 2 of Set 3 | new norfolk
# Processing Record 3 of Set 3 | sisimiut
# Processing Record 4 of Set 3 | sindor
# Processing Record 5 of Set 3 | pravda
# Processing Record 6 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 3 | buala
# Processing Record 8 of Set 3 | puerto cabezas
# Processing Record 9 of Set 3 | busselton
# Processing Record 10 of Set 3 | butaritari
# Processing Record 11 of Set 3 | amga
# Processing Record 12 of Set 3 | teodoro sampaio
# Processing Record 13 of Set 3 | amapa
# Processing Record 14 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 3 | maldonado
# Processing Record 16 of Set 3 | manakara
# Processing Record 17 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 18 of Set 3 | porto belo
# Processing Record 19 of Set 3 | zyryanovsk
# Processing Record 20 of Set 3 | ginir
# Processing Record 21 of Set 3 | aklavik
# Processing Record 22 of Set 3 | scottsburgh
# City not found. Skipping...
# Processing Record 23 of Set 3 | port-cartier
# Processing Record 24 of Set 3 | auki
# Processing Record 25 of Set 3 | medina del campo
# Processing Record 26 of Set 3 | wajima
# Processing Record 27 of Set 3 | malinovoye ozero
# Processing Record 28 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 3 | pemangkat
# Processing Record 30 of Set 3 | portland
# Processing Record 31 of Set 3 | rawson
# Processing Record 32 of Set 3 | chuy
# Processing Record 33 of Set 3 | narsaq
# Processing Record 34 of Set 3 | ust-maya
# Processing Record 35 of Set 3 | rimouski
# Processing Record 36 of Set 3 | itarema
# Processing Record 37 of Set 3 | morondava
# Processing Record 38 of Set 3 | saint-augustin
# Processing Record 39 of Set 3 | sobolevo
# Processing Record 40 of Set 3 | tasiilaq
# Processing Record 41 of Set 3 | beringovskiy
# Processing Record 42 of Set 3 | podgornoye
# Processing Record 43 of Set 3 | vaini
# Processing Record 44 of Set 3 | lorengau
# Processing Record 45 of Set 3 | andenes
# Processing Record 46 of Set 3 | husavik
# Processing Record 47 of Set 3 | camacha
# Processing Record 48 of Set 3 | amarillo
# Processing Record 49 of Set 3 | bangkalan
# Processing Record 50 of Set 3 | fort nelson
# Processing Record 1 of Set 4 | mehamn
# Processing Record 2 of Set 4 | zaozerne
# Processing Record 3 of Set 4 | kitimat
# Processing Record 4 of Set 4 | dandong
# Processing Record 5 of Set 4 | taoudenni
# Processing Record 6 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 4 | cabo san lucas
# Processing Record 8 of Set 4 | bubaque
# Processing Record 9 of Set 4 | russell
# Processing Record 10 of Set 4 | port elizabeth
# Processing Record 11 of Set 4 | east london
# Processing Record 12 of Set 4 | bellevue
# Processing Record 13 of Set 4 | tura
# Processing Record 14 of Set 4 | hasaki
# Processing Record 15 of Set 4 | dagua
# Processing Record 16 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 4 | yulara
# Processing Record 18 of Set 4 | sola
# Processing Record 19 of Set 4 | bilibino
# Processing Record 20 of Set 4 | kaitangata
# Processing Record 21 of Set 4 | radcliff
# Processing Record 22 of Set 4 | mackenzie
# Processing Record 23 of Set 4 | el tigre
# Processing Record 24 of Set 4 | salalah
# Processing Record 25 of Set 4 | kidal
# Processing Record 26 of Set 4 | mondlo
# Processing Record 27 of Set 4 | ushirombo
# Processing Record 28 of Set 4 | nantucket
# Processing Record 29 of Set 4 | mahebourg
# Processing Record 30 of Set 4 | ilulissat
# Processing Record 31 of Set 4 | agapovka
# Processing Record 32 of Set 4 | coihaique
# Processing Record 33 of Set 4 | nabire
# Processing Record 34 of Set 4 | skibotn
# Processing Record 35 of Set 4 | seminole
# Processing Record 36 of Set 4 | hilo
# Processing Record 37 of Set 4 | paracuru
# Processing Record 38 of Set 4 | babushkin
# Processing Record 39 of Set 4 | enid
# Processing Record 40 of Set 4 | geraldton
# Processing Record 41 of Set 4 | saint-pierre
# Processing Record 42 of Set 4 | odessa
# Processing Record 43 of Set 4 | douglas
# Processing Record 44 of Set 4 | bondoukou
# Processing Record 45 of Set 4 | zhigansk
# Processing Record 46 of Set 4 | tessalit
# Processing Record 47 of Set 4 | san jose
# Processing Record 48 of Set 4 | arandis
# Processing Record 49 of Set 4 | padang
# Processing Record 50 of Set 4 | ulaangom
# Processing Record 1 of Set 5 | upata
# Processing Record 2 of Set 5 | phonhong
# Processing Record 3 of Set 5 | fukue
# Processing Record 4 of Set 5 | coos bay
# Processing Record 5 of Set 5 | tocopilla
# Processing Record 6 of Set 5 | gunjur
# Processing Record 7 of Set 5 | dryden
# Processing Record 8 of Set 5 | cabedelo
# Processing Record 9 of Set 5 | sartana
# Processing Record 10 of Set 5 | berezovyy
# Processing Record 11 of Set 5 | imbituba
# Processing Record 12 of Set 5 | bulgan
# Processing Record 13 of Set 5 | north bend
# Processing Record 14 of Set 5 | naze
# Processing Record 15 of Set 5 | ternate
# Processing Record 16 of Set 5 | dillon
# Processing Record 17 of Set 5 | leningradskiy
# Processing Record 18 of Set 5 | puerto madryn
# Processing Record 19 of Set 5 | roma
# Processing Record 20 of Set 5 | bilma
# Processing Record 21 of Set 5 | mossendjo
# Processing Record 22 of Set 5 | boguchany
# Processing Record 23 of Set 5 | valentin gomez farias
# Processing Record 24 of Set 5 | broken hill
# Processing Record 25 of Set 5 | carutapera
# Processing Record 26 of Set 5 | bat khela
# Processing Record 27 of Set 5 | voh
# Processing Record 28 of Set 5 | altea
# Processing Record 29 of Set 5 | kahului
# Processing Record 30 of Set 5 | gamba
# Processing Record 31 of Set 5 | conceicao da barra
# Processing Record 32 of Set 5 | rivne
# Processing Record 33 of Set 5 | los llanos de aridane
# Processing Record 34 of Set 5 | tecoanapa
# Processing Record 35 of Set 5 | bardiyah
# Processing Record 36 of Set 5 | bandarbeyla
# Processing Record 37 of Set 5 | biltine
# Processing Record 38 of Set 5 | san patricio
# Processing Record 39 of Set 5 | henties bay
# Processing Record 40 of Set 5 | nzega
# Processing Record 41 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 42 of Set 5 | naujamiestis
# Processing Record 43 of Set 5 | torbay
# Processing Record 44 of Set 5 | vung tau
# Processing Record 45 of Set 5 | bluff
# Processing Record 46 of Set 5 | honggang
# Processing Record 47 of Set 5 | champerico
# Processing Record 48 of Set 5 | mobaye
# Processing Record 49 of Set 5 | tual
# Processing Record 50 of Set 5 | aswan
# Processing Record 1 of Set 6 | namatanai
# Processing Record 2 of Set 6 | fortuna
# Processing Record 3 of Set 6 | port macquarie
# Processing Record 4 of Set 6 | asayita
# City not found. Skipping...
# Processing Record 5 of Set 6 | upernavik
# Processing Record 6 of Set 6 | snezhnogorsk
# Processing Record 7 of Set 6 | dikson
# Processing Record 8 of Set 6 | ginda
# Processing Record 9 of Set 6 | pevek
# Processing Record 10 of Set 6 | port alfred
# Processing Record 11 of Set 6 | severo-kurilsk
# Processing Record 12 of Set 6 | lompoc
# Processing Record 13 of Set 6 | mar del plata
# Processing Record 14 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 6 | luwuk
# Processing Record 16 of Set 6 | tuatapere
# Processing Record 17 of Set 6 | alice springs
# Processing Record 18 of Set 6 | grindavik
# Processing Record 19 of Set 6 | ostersund
# Processing Record 20 of Set 6 | castro
# Processing Record 21 of Set 6 | vallenar
# Processing Record 22 of Set 6 | puerto escondido
# Processing Record 23 of Set 6 | takoradi
# Processing Record 24 of Set 6 | iqaluit
# Processing Record 25 of Set 6 | mayo
# Processing Record 26 of Set 6 | clyde river
# Processing Record 27 of Set 6 | dordrecht
# Processing Record 28 of Set 6 | borama
# City not found. Skipping...
# Processing Record 29 of Set 6 | baghdad
# Processing Record 30 of Set 6 | katangli
# Processing Record 31 of Set 6 | poronaysk
# Processing Record 32 of Set 6 | jinchengjiang
# City not found. Skipping...
# Processing Record 33 of Set 6 | ajdabiya
# Processing Record 34 of Set 6 | arroio grande
# Processing Record 35 of Set 6 | alyangula
# Processing Record 36 of Set 6 | nioro
# Processing Record 37 of Set 6 | ukiah
# Processing Record 38 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 39 of Set 6 | charters towers
# Processing Record 40 of Set 6 | san cristobal
# Processing Record 41 of Set 6 | lamu
# Processing Record 42 of Set 6 | lemesos
# City not found. Skipping...
# Processing Record 43 of Set 6 | sitka
# Processing Record 44 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 6 | cavalcante
# Processing Record 46 of Set 6 | halifax
# Processing Record 47 of Set 6 | srednekolymsk
# Processing Record 48 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 6 | ostrovnoy
# Processing Record 50 of Set 6 | vostok
# Processing Record 1 of Set 7 | khawhai
# Processing Record 2 of Set 7 | acapulco
# Processing Record 3 of Set 7 | palana
# Processing Record 4 of Set 7 | flin flon
# Processing Record 5 of Set 7 | kyaukse
# Processing Record 6 of Set 7 | vagur
# Processing Record 7 of Set 7 | le vauclin
# Processing Record 8 of Set 7 | jumla
# Processing Record 9 of Set 7 | geresk
# City not found. Skipping...
# Processing Record 10 of Set 7 | taloqan
# Processing Record 11 of Set 7 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 12 of Set 7 | laguna
# Processing Record 13 of Set 7 | tashtyp
# Processing Record 14 of Set 7 | pinega
# Processing Record 15 of Set 7 | pisco
# Processing Record 16 of Set 7 | payson
# Processing Record 17 of Set 7 | cochrane
# Processing Record 18 of Set 7 | sao filipe
# Processing Record 19 of Set 7 | soimari
# Processing Record 20 of Set 7 | punta alta
# Processing Record 21 of Set 7 | susanville
# Processing Record 22 of Set 7 | bahadurganj
# Processing Record 23 of Set 7 | coahuayana
# Processing Record 24 of Set 7 | saldanha
# Processing Record 25 of Set 7 | oriximina
# Processing Record 26 of Set 7 | bethel
# Processing Record 27 of Set 7 | guane
# Processing Record 28 of Set 7 | podgorodnyaya pokrovka
# Processing Record 29 of Set 7 | zharkent
# Processing Record 30 of Set 7 | haines junction
# Processing Record 31 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 7 | daru
# Processing Record 33 of Set 7 | okhotsk
# Processing Record 34 of Set 7 | anshun
# Processing Record 35 of Set 7 | odienne
# Processing Record 36 of Set 7 | vaitape
# Processing Record 37 of Set 7 | waipawa
# Processing Record 38 of Set 7 | neuquen
# Processing Record 39 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 7 | maridi
# Processing Record 41 of Set 7 | velizh
# Processing Record 42 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 7 | almaznyy
# Processing Record 44 of Set 7 | codrington
# Processing Record 45 of Set 7 | bud
# Processing Record 46 of Set 7 | melioratorov
# Processing Record 47 of Set 7 | kihei
# Processing Record 48 of Set 7 | sept-iles
# Processing Record 49 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 50 of Set 7 | fairbanks
# Processing Record 1 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 2 of Set 8 | batagay-alyta
# Processing Record 3 of Set 8 | kurilsk
# Processing Record 4 of Set 8 | yuzhno-kurilsk
# Processing Record 5 of Set 8 | mount gambier
# Processing Record 6 of Set 8 | sandwick
# Processing Record 7 of Set 8 | waingapu
# Processing Record 8 of Set 8 | majene
# Processing Record 9 of Set 8 | lagunas
# Processing Record 10 of Set 8 | robertsport
# Processing Record 11 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 8 | vila velha
# Processing Record 13 of Set 8 | viedma
# Processing Record 14 of Set 8 | vega de alatorre
# Processing Record 15 of Set 8 | zaraza
# Processing Record 16 of Set 8 | ulaanbaatar
# Processing Record 17 of Set 8 | dukat
# Processing Record 18 of Set 8 | lazaro cardenas
# Processing Record 19 of Set 8 | aykhal
# Processing Record 20 of Set 8 | qarayeri
# Processing Record 21 of Set 8 | ribeira brava
# Processing Record 22 of Set 8 | griffith
# Processing Record 23 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 24 of Set 8 | burnie
# Processing Record 25 of Set 8 | calvinia
# Processing Record 26 of Set 8 | namtsy
# Processing Record 27 of Set 8 | tayu
# Processing Record 28 of Set 8 | marawi
# Processing Record 29 of Set 8 | kirakira
# Processing Record 30 of Set 8 | mineiros
# Processing Record 31 of Set 8 | valpacos
# Processing Record 32 of Set 8 | tigil
# Processing Record 33 of Set 8 | point fortin
# Processing Record 34 of Set 8 | sosva
# Processing Record 35 of Set 8 | ahipara
# Processing Record 36 of Set 8 | sembe
# Processing Record 37 of Set 8 | banda aceh
# Processing Record 38 of Set 8 | poum
# Processing Record 39 of Set 8 | faanui
# Processing Record 40 of Set 8 | sampit
# Processing Record 41 of Set 8 | rafai
# Processing Record 42 of Set 8 | deputatskiy
# Processing Record 43 of Set 8 | tairua
# Processing Record 44 of Set 8 | pacaembu
# Processing Record 45 of Set 8 | gollere
# City not found. Skipping...
# Processing Record 46 of Set 8 | yarada
# Processing Record 47 of Set 8 | mogadishu
# Processing Record 48 of Set 8 | talnakh
# Processing Record 49 of Set 8 | manono
# Processing Record 50 of Set 8 | keti bandar
# Processing Record 1 of Set 9 | krasne
# Processing Record 2 of Set 9 | islamkot
# Processing Record 3 of Set 9 | akyab
# Processing Record 4 of Set 9 | airai
# Processing Record 5 of Set 9 | acarau
# Processing Record 6 of Set 9 | sioux lookout
# Processing Record 7 of Set 9 | santa marta
# Processing Record 8 of Set 9 | la asuncion
# Processing Record 9 of Set 9 | eyl
# Processing Record 10 of Set 9 | aquiraz
# Processing Record 11 of Set 9 | otane
# Processing Record 12 of Set 9 | kijang
# Processing Record 13 of Set 9 | san policarpo
# Processing Record 14 of Set 9 | hamilton
# Processing Record 15 of Set 9 | sorong
# Processing Record 16 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 18 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 9 | goundam
# Processing Record 20 of Set 9 | konispol
# Processing Record 21 of Set 9 | lagoa
# Processing Record 22 of Set 9 | saint anthony
# Processing Record 23 of Set 9 | bacabal
# Processing Record 24 of Set 9 | tamandare
# Processing Record 25 of Set 9 | shingu
# Processing Record 26 of Set 9 | nova olimpia
# Processing Record 27 of Set 9 | marsh harbour
# Processing Record 28 of Set 9 | spring hill
# Processing Record 29 of Set 9 | colares
# Processing Record 30 of Set 9 | kabo
# Processing Record 31 of Set 9 | baharampur
# Processing Record 32 of Set 9 | guajara-mirim
# City not found. Skipping...
# Processing Record 33 of Set 9 | mukerian
# Processing Record 34 of Set 9 | vytegra
# Processing Record 35 of Set 9 | broome
# Processing Record 36 of Set 9 | victoria
# Processing Record 37 of Set 9 | odweyne
# Processing Record 38 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 9 | cherskiy
# Processing Record 40 of Set 9 | irbeyskoye
# Processing Record 41 of Set 9 | saint austell
# Processing Record 42 of Set 9 | nizwa
# Processing Record 43 of Set 9 | muskogee
# Processing Record 44 of Set 9 | mangrol
# Processing Record 45 of Set 9 | kongolo
# Processing Record 46 of Set 9 | harper
# Processing Record 47 of Set 9 | ramanagaram
# Processing Record 48 of Set 9 | oboyan
# Processing Record 49 of Set 9 | zhanaozen
# Processing Record 50 of Set 9 | hokitika
# Processing Record 1 of Set 10 | sabha
# Processing Record 2 of Set 10 | nome
# Processing Record 3 of Set 10 | minot
# Processing Record 4 of Set 10 | batemans bay
# Processing Record 5 of Set 10 | nea kerasia
# Processing Record 6 of Set 10 | kampong thum
# Processing Record 7 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 10 | chabahar
# Processing Record 9 of Set 10 | lakes entrance
# Processing Record 10 of Set 10 | norrtalje
# Processing Record 11 of Set 10 | palafrugell
# Processing Record 12 of Set 10 | hofn
# Processing Record 13 of Set 10 | gari
# Processing Record 14 of Set 10 | hualmay
# Processing Record 15 of Set 10 | paita
# Processing Record 16 of Set 10 | port hedland
# Processing Record 17 of Set 10 | goulburn
# Processing Record 18 of Set 10 | buesaco
# Processing Record 19 of Set 10 | klaksvik
# Processing Record 20 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 10 | clearwater
# Processing Record 22 of Set 10 | nara
# Processing Record 23 of Set 10 | saryozek
# Processing Record 24 of Set 10 | ibra
# Processing Record 25 of Set 10 | kibala
# Processing Record 26 of Set 10 | baykit
# Processing Record 27 of Set 10 | moose factory
# Processing Record 28 of Set 10 | muyezerskiy
# Processing Record 29 of Set 10 | bose
# Processing Record 30 of Set 10 | inirida
# Processing Record 31 of Set 10 | saint-georges
# Processing Record 32 of Set 10 | balkhash
# Processing Record 33 of Set 10 | kayseri
# Processing Record 34 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 10 | port shepstone
# Processing Record 36 of Set 10 | petersburg
# Processing Record 37 of Set 10 | enshi
# Processing Record 38 of Set 10 | kemin
# Processing Record 39 of Set 10 | tadine
# Processing Record 40 of Set 10 | huarmey
# Processing Record 41 of Set 10 | houma
# Processing Record 42 of Set 10 | ekhabi
# Processing Record 43 of Set 10 | santa cruz
# Processing Record 44 of Set 10 | lukovetskiy
# Processing Record 45 of Set 10 | kolchugino
# Processing Record 46 of Set 10 | xenia
# Processing Record 47 of Set 10 | kapit
# Processing Record 48 of Set 10 | sault sainte marie
# Processing Record 49 of Set 10 | quatre cocos
# Processing Record 50 of Set 10 | bereda
# Processing Record 1 of Set 11 | bathurst
# Processing Record 2 of Set 11 | trelew
# Processing Record 3 of Set 11 | labuhan
# Processing Record 4 of Set 11 | altay
# Processing Record 5 of Set 11 | bireun
# Processing Record 6 of Set 11 | corowa
# Processing Record 7 of Set 11 | punta de piedra
# Processing Record 8 of Set 11 | faya
# Processing Record 9 of Set 11 | beruni
# City not found. Skipping...
# Processing Record 10 of Set 11 | gazojak
# Processing Record 11 of Set 11 | tokoroa
# Processing Record 12 of Set 11 | verkhnyaya toyma
# Processing Record 13 of Set 11 | liverpool
# Processing Record 14 of Set 11 | nuuk
# Processing Record 15 of Set 11 | indianola
# Processing Record 16 of Set 11 | vila franca do campo
# Processing Record 17 of Set 11 | todos santos
# Processing Record 18 of Set 11 | kaputa
# Processing Record 19 of Set 11 | sharjah
# Processing Record 20 of Set 11 | te anau
# Processing Record 21 of Set 11 | karratha
# Processing Record 22 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 23 of Set 11 | luderitz
# Processing Record 24 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 25 of Set 11 | renqiu
# Processing Record 26 of Set 11 | tarakan
# Processing Record 27 of Set 11 | komsomolskiy
# Processing Record 28 of Set 11 | kaseda
# Processing Record 29 of Set 11 | abha
# Processing Record 30 of Set 11 | glencoe
# Processing Record 31 of Set 11 | raymond
# Processing Record 32 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 33 of Set 11 | sikonge
# Processing Record 34 of Set 11 | northam
# Processing Record 35 of Set 11 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 36 of Set 11 | bengkulu
# Processing Record 37 of Set 11 | isangel
# Processing Record 38 of Set 11 | ketchikan
# Processing Record 39 of Set 11 | pareora
# Processing Record 40 of Set 11 | valparaiso
# Processing Record 41 of Set 11 | inta
# Processing Record 42 of Set 11 | palauig
# Processing Record 43 of Set 11 | crystal beach
# Processing Record 44 of Set 11 | gao
# Processing Record 45 of Set 11 | talara
# Processing Record 46 of Set 11 | ixtapa
# Processing Record 47 of Set 11 | callaguip
# Processing Record 48 of Set 11 | qasigiannguit
# Processing Record 49 of Set 11 | kavaratti
# Processing Record 50 of Set 11 | rondonopolis
# Processing Record 1 of Set 12 | wembley
# Processing Record 2 of Set 12 | port lincoln
# Processing Record 3 of Set 12 | caldwell
# Processing Record 4 of Set 12 | taltal
# Processing Record 5 of Set 12 | guaira
# Processing Record 6 of Set 12 | seoul
# Processing Record 7 of Set 12 | flagstaff
# Processing Record 8 of Set 12 | malanje
# Processing Record 9 of Set 12 | sorland
# Processing Record 10 of Set 12 | machinga
# Processing Record 11 of Set 12 | yar-sale
# Processing Record 12 of Set 12 | miyako
# Processing Record 13 of Set 12 | potiskum
# Processing Record 14 of Set 12 | navahrudak
# Processing Record 15 of Set 12 | korla
# Processing Record 16 of Set 12 | inyonga
# Processing Record 17 of Set 12 | krasnyy chikoy
# Processing Record 18 of Set 12 | iguatu
# Processing Record 19 of Set 12 | boende
# Processing Record 20 of Set 12 | aripuana
# Processing Record 21 of Set 12 | konosha
# Processing Record 22 of Set 12 | nahrin
# Processing Record 23 of Set 12 | illapel
# Processing Record 24 of Set 12 | port-gentil
# Processing Record 25 of Set 12 | norman wells
# Processing Record 26 of Set 12 | kenai
# Processing Record 27 of Set 12 | sosnovo
# Processing Record 28 of Set 12 | alta floresta
# Processing Record 29 of Set 12 | hammerfest
# Processing Record 30 of Set 12 | bestobe
# Processing Record 31 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 12 | marienburg
# Processing Record 33 of Set 12 | ampanihy
# Processing Record 34 of Set 12 | kalabo
# Processing Record 35 of Set 12 | half moon bay
# Processing Record 36 of Set 12 | itacare
# Processing Record 37 of Set 12 | rudnichnyy
# Processing Record 38 of Set 12 | souillac
# Processing Record 39 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 40 of Set 12 | emerald
# Processing Record 41 of Set 12 | nagorsk
# Processing Record 42 of Set 12 | krasnoselkup
# Processing Record 43 of Set 12 | coruripe
# Processing Record 44 of Set 12 | yeppoon
# Processing Record 45 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 46 of Set 12 | daoukro
# Processing Record 47 of Set 12 | pitimbu
# Processing Record 48 of Set 12 | westport
# Processing Record 49 of Set 12 | wuchang
# Processing Record 50 of Set 12 | trincomalee
# Processing Record 1 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 2 of Set 13 | gainesville
# Processing Record 3 of Set 13 | makurdi
# Processing Record 4 of Set 13 | kurchum
# Processing Record 5 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 13 | praia
# Processing Record 7 of Set 13 | monrovia
# Processing Record 8 of Set 13 | bobonong
# City not found. Skipping...
# Processing Record 9 of Set 13 | pangnirtung
# Processing Record 10 of Set 13 | shu
# Processing Record 11 of Set 13 | mehran
# Processing Record 12 of Set 13 | tibu
# Processing Record 13 of Set 13 | hambantota
# Processing Record 14 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 13 | chizhou
# Processing Record 16 of Set 13 | langsa
# Processing Record 17 of Set 13 | burhaniye
# Processing Record 18 of Set 13 | skegness
# Processing Record 19 of Set 13 | iida
# Processing Record 20 of Set 13 | sol-iletsk
# Processing Record 21 of Set 13 | taywarah
# Processing Record 22 of Set 13 | lavrentiya
# Processing Record 23 of Set 13 | homer
# Processing Record 24 of Set 13 | zhicheng
# Processing Record 25 of Set 13 | yangambi
# Processing Record 26 of Set 13 | makat
# Processing Record 27 of Set 13 | lodwar
# Processing Record 28 of Set 13 | dibulla
# Processing Record 29 of Set 13 | cloquet
# Processing Record 30 of Set 13 | aksarka
# Processing Record 31 of Set 13 | svetlogorsk
# Processing Record 32 of Set 13 | inhambane
# Processing Record 33 of Set 13 | nokaneng
# Processing Record 34 of Set 13 | tahta
# Processing Record 35 of Set 13 | vyazemskiy
# Processing Record 36 of Set 13 | maragogi
# Processing Record 37 of Set 13 | havelock
# Processing Record 38 of Set 13 | sharanga
# Processing Record 39 of Set 13 | gilgit
# Processing Record 40 of Set 13 | sabalgarh
# Processing Record 41 of Set 13 | konstantinovskoye
# Processing Record 42 of Set 13 | sterling
# Processing Record 43 of Set 13 | hirtshals
# Processing Record 44 of Set 13 | ankara
# Processing Record 45 of Set 13 | sao jose da coroa grande
# Processing Record 46 of Set 13 | kamaishi
# Processing Record 47 of Set 13 | simao
# Processing Record 48 of Set 13 | chomun
# City not found. Skipping...
# Processing Record 49 of Set 13 | awbari
# Processing Record 50 of Set 13 | leshan
# Processing Record 1 of Set 14 | tafresh
# Processing Record 2 of Set 14 | maniitsoq
# Processing Record 3 of Set 14 | zhezkazgan
# Processing Record 4 of Set 14 | port ellen
# City not found. Skipping...
# Processing Record 5 of Set 14 | sarakhs
# Processing Record 6 of Set 14 | guiberoua
# Processing Record 7 of Set 14 | americus
# Processing Record 8 of Set 14 | paamiut
# Processing Record 9 of Set 14 | dwarka
# Processing Record 10 of Set 14 | tikrit
# Processing Record 11 of Set 14 | alofi
# Processing Record 12 of Set 14 | zhenjiang
# Processing Record 13 of Set 14 | cabo rojo
# Processing Record 14 of Set 14 | preobrazheniye
# Processing Record 15 of Set 14 | byron bay
# Processing Record 16 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 17 of Set 14 | lamar
# Processing Record 18 of Set 14 | saint-louis
# Processing Record 19 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 20 of Set 14 | brooks
# Processing Record 21 of Set 14 | shizuishan
# Processing Record 22 of Set 14 | hami
# Processing Record 23 of Set 14 | christchurch
# Processing Record 24 of Set 14 | nizhnyaya omka
# Processing Record 25 of Set 14 | hay river
# Processing Record 26 of Set 14 | santa rosa
# Processing Record 27 of Set 14 | nikolayevsk-na-amure
# Processing Record 28 of Set 14 | aleksandrov
# Processing Record 29 of Set 14 | hovd
# Processing Record 30 of Set 14 | kulhudhuffushi
# Processing Record 31 of Set 14 | canutama
# Processing Record 32 of Set 14 | sao joao da barra
# Processing Record 33 of Set 14 | kongwa
# Processing Record 34 of Set 14 | misratah
# Processing Record 35 of Set 14 | madang
# Processing Record 36 of Set 14 | kayerkan
# Processing Record 37 of Set 14 | cootamundra
# Processing Record 38 of Set 14 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 39 of Set 14 | peniche
# Processing Record 40 of Set 14 | kieta
# Processing Record 41 of Set 14 | dubenskiy
# City not found. Skipping...
# Processing Record 42 of Set 14 | san bernardo
# Processing Record 43 of Set 14 | wagar
# Processing Record 44 of Set 14 | dunedin
# Processing Record 45 of Set 14 | palmer
# Processing Record 46 of Set 14 | kumbhraj
# Processing Record 47 of Set 14 | sarahan
# Processing Record 48 of Set 14 | yambio
# Processing Record 49 of Set 14 | manuk mangkaw
# Processing Record 50 of Set 14 | brigantine
# Processing Record 1 of Set 15 | kuusamo
# Processing Record 2 of Set 15 | quang ngai
# Processing Record 3 of Set 15 | tambacounda
# Processing Record 4 of Set 15 | terrace
# Processing Record 5 of Set 15 | aromashevo
# Processing Record 6 of Set 15 | japura
# Processing Record 7 of Set 15 | vanavara
# Processing Record 8 of Set 15 | rodos
# Processing Record 9 of Set 15 | araouane
# Processing Record 10 of Set 15 | hondo
# Processing Record 11 of Set 15 | riaba
# City not found. Skipping...
# Processing Record 12 of Set 15 | truth or consequences
# Processing Record 13 of Set 15 | dzerzhinsk
# Processing Record 14 of Set 15 | norilsk
# Processing Record 15 of Set 15 | pundaguitan
# Processing Record 16 of Set 15 | flinders
# Processing Record 17 of Set 15 | general roca
# Processing Record 18 of Set 15 | chornukhy
# Processing Record 19 of Set 15 | guerrero negro
# Processing Record 20 of Set 15 | bahia honda
# Processing Record 21 of Set 15 | victor harbor
# Processing Record 22 of Set 15 | necochea
# Processing Record 23 of Set 15 | vanderhoof
# Processing Record 24 of Set 15 | zastron
# Processing Record 25 of Set 15 | eskisehir
# Processing Record 26 of Set 15 | kyshtovka
# Processing Record 27 of Set 15 | maxixe
# Processing Record 28 of Set 15 | jahrom
# City not found. Skipping...
# Processing Record 29 of Set 15 | adre
# Processing Record 30 of Set 15 | mecca
# Processing Record 31 of Set 15 | ahuimanu
# Processing Record 32 of Set 15 | namibe
# Processing Record 33 of Set 15 | minab
# Processing Record 34 of Set 15 | jodoigne
# Processing Record 35 of Set 15 | bandar-e lengeh
# Processing Record 36 of Set 15 | teya
# Processing Record 37 of Set 15 | newport
# Processing Record 38 of Set 15 | kombissiri
# Processing Record 39 of Set 15 | marrakesh
# Processing Record 40 of Set 15 | bacuit
# City not found. Skipping...
# Processing Record 41 of Set 15 | kobayashi
# Processing Record 42 of Set 15 | kichera
# Processing Record 43 of Set 15 | turukhansk
# Processing Record 44 of Set 15 | batticaloa
# Processing Record 45 of Set 15 | saint-michel-des-saints
# Processing Record 46 of Set 15 | manokwari
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0        Indian Head      US  38.6001  -77.1622     50.16        59
# 1             Albany      US  42.6001  -73.9662     36.63        82
# 2            Rikitea      PF -23.1203 -134.9692     78.75        70
# 3     Saint-Philippe      RE -21.3585   55.7679     76.59        84
# 4           Cidreira      BR -30.1811  -50.2056     74.50        87
# 5         Bredasdorp      ZA -34.5322   20.0403     60.12        88
# 6  Nizhniy Tsasuchey      RU  50.5167  115.1333     16.03        50
# 7          Jamestown      US  42.0970  -79.2353     33.03        57
# 8            Qaanaaq      GL  77.4840  -69.3632     -6.23        80
# 9               Vila      PT  42.0304   -8.1588     40.69        93
#
#    Cloudiness  Wind Speed Current Description
# 0         100        5.75     overcast clouds
# 1          87        2.93     overcast clouds
# 2          13        6.62          few clouds
# 3          37        8.05    scattered clouds
# 4          99        2.71     overcast clouds
# 5           0        3.44           clear sky
# 6           0        7.47           clear sky
# 7           0        5.75           clear sky
# 8         100        2.10     overcast clouds
# 9         100       11.18          light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
